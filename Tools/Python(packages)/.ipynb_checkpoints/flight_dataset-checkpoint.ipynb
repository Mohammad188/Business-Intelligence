# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# ## Read the Dataset

# %%
import numpy as np 
import pandas as pd

# %%
path = 'F:\DS Projects\Datasets\Combined_Flights_2022.csv'
df = pd.read_csv(path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_11816\7532545.py:1: SyntaxWarning: invalid escape sequence '\D'
#   path = 'F:\DS Projects\Datasets\Combined_Flights_2022.csv'

# %% [markdown]
# ## Explore on dataset

# %%
df.shape, len(df)
# Out:
# ((4078318, 61), 4078318)

# %%
df.head()
# Out:
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ...  \
# 0      False     False        1133   1123.0              0.0     -10.0  ...
# 1      False     False         732    728.0              0.0      -4.0  ...
# 2      False     False        1529   1514.0              0.0     -15.0  ...
# 3      False     False        1435   1430.0              0.0      -5.0  ...
# 4      False     False        1135   1135.0              0.0       0.0  ...
#
#    WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrDelay  ArrDel15  \
# ...

# %%
pd.set_option("display.max_columns", 100)

# %%
df.head()
# Out:
#    FlightDate                                    Airline Origin Dest  \
# 0  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4  2022-04-04  Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
#
#    Cancelled  Diverted  CRSDepTime  DepTime  DepDelayMinutes  DepDelay  \
# 0      False     False        1133   1123.0              0.0     -10.0
# 1      False     False         732    728.0              0.0      -4.0
# 2      False     False        1529   1514.0              0.0     -15.0
# 3      False     False        1435   1430.0              0.0      -5.0
# 4      False     False        1135   1135.0              0.0       0.0
#
#    ArrTime  ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
df.tail()
# Out:
#          FlightDate            Airline Origin Dest  Cancelled  Diverted  \
# 4078313  2022-03-31  Republic Airlines    MSY  EWR      False      True
# 4078314  2022-03-17  Republic Airlines    CLT  EWR       True     False
# 4078315  2022-03-08  Republic Airlines    ALB  ORD      False     False
# 4078316  2022-03-25  Republic Airlines    EWR  PIT      False      True
# 4078317  2022-03-07  Republic Airlines    EWR  RDU      False      True
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 4078313        1949   2014.0             25.0      25.0    234.0
# 4078314        1733   1817.0             44.0      44.0      NaN
# 4078315        1700   2318.0            378.0     378.0     59.0
# 4078316        2129   2322.0            113.0     113.0    939.0
# 4078317        1154   1148.0              0.0      -6.0   1556.0
#
#          ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
df.sample(5, random_state=42)
# Out:
#          FlightDate                 Airline Origin Dest  Cancelled  Diverted  \
# 3811797  2022-03-19   SkyWest Airlines Inc.    ASE  DEN      False     False
# 615029   2022-02-16   SkyWest Airlines Inc.    TYS  DEN      False     False
# 3228533  2022-01-18  American Airlines Inc.    LAX  OGG      False     False
# 3129490  2022-01-23  Southwest Airlines Co.    LAS  BWI      False     False
# 1273418  2022-07-01    Delta Air Lines Inc.    DTW  RDU      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 3811797        1831   1826.0              0.0      -5.0   1923.0
# 615029         1605   1605.0              0.0       0.0   1812.0
# 3228533        1719   1714.0              0.0      -5.0   2052.0
# 3129490        1515   1533.0             18.0      18.0   2302.0
# 1273418         715    709.0              0.0      -6.0    837.0
#
#          ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4078318 entries, 0 to 4078317
# Data columns (total 61 columns):
#  #   Column                                   Dtype
# ---  ------                                   -----
#  0   FlightDate                               object
#  1   Airline                                  object
#  2   Origin                                   object
#  3   Dest                                     object
#  4   Cancelled                                bool
#  5   Diverted                                 bool
#  6   CRSDepTime                               int64
#  7   DepTime                                  float64
#  8   DepDelayMinutes                          float64
#  9   DepDelay                                 float64
#  10  ArrTime                                  float64
#  11  ArrDelayMinutes                          float64
#  12  AirTime                                  float64
#  13  CRSElapsedTime                           float64
# ...

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4078318 entries, 0 to 4078317
# Columns: 61 entries, FlightDate to DivAirportLandings
# dtypes: bool(2), float64(18), int64(23), object(18)
# memory usage: 1.8+ GB

# %%
df.describe(percentiles=[0.2, 0.4, 0.6, 0.8])
# Out:
#          CRSDepTime       DepTime  DepDelayMinutes      DepDelay  \
# count  4.078318e+06  3.957885e+06     3.957823e+06  3.957823e+06
# mean   1.329587e+03  1.334374e+03     1.601494e+01  1.309049e+01
# std    4.904801e+02  5.056219e+02     5.231498e+01  5.332016e+01
# min    1.000000e+00  1.000000e+00     0.000000e+00 -7.800000e+01
# 20%    8.290000e+02  8.280000e+02     0.000000e+00 -6.000000e+00
# 40%    1.140000e+03  1.144000e+03     0.000000e+00 -3.000000e+00
# 50%    1.320000e+03  1.325000e+03     0.000000e+00 -2.000000e+00
# 60%    1.500000e+03  1.508000e+03     0.000000e+00  0.000000e+00
# 80%    1.823000e+03  1.833000e+03     1.700000e+01  1.700000e+01
# max    2.359000e+03  2.400000e+03     7.223000e+03  7.223000e+03
#
#             ArrTime  ArrDelayMinutes       AirTime  CRSElapsedTime  \
# count  3.954079e+06     3.944916e+06  3.944916e+06    4.078318e+06
# mean   1.457886e+03     1.578307e+01  1.110075e+02    1.413211e+02
# ...

# %%
df.describe(include=['object'])
# Out:
#         FlightDate                 Airline   Origin     Dest  \
# count      4078318                 4078318  4078318  4078318
# unique         212                      21      375      375
# top     2022-07-21  Southwest Airlines Co.      ATL      ATL
# freq         20844                  731925   183697   183671
#
#        Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# count                    4078318                                 4078318
# unique                        10                                      14
# top                           AA                                      WN
# freq                     1043530                                  731925
#
#        IATA_Code_Marketing_Airline Operating_Airline  \
# count                      4078318           4078318
# unique                          10                21
# top                             AA                WN
# freq                       1043530            731925
#
# ...

# %%
df.describe(exclude=['int64', 'object'])
# Out:
#        Cancelled Diverted       DepTime  DepDelayMinutes      DepDelay  \
# count    4078318  4078318  3.957885e+06     3.957823e+06  3.957823e+06
# unique         2        2           NaN              NaN           NaN
# top        False    False           NaN              NaN           NaN
# freq     3955126  4068108           NaN              NaN           NaN
# mean         NaN      NaN  1.334374e+03     1.601494e+01  1.309049e+01
# std          NaN      NaN  5.056219e+02     5.231498e+01  5.332016e+01
# min          NaN      NaN  1.000000e+00     0.000000e+00 -7.800000e+01
# 25%          NaN      NaN  9.170000e+02     0.000000e+00 -5.000000e+00
# 50%          NaN      NaN  1.325000e+03     0.000000e+00 -2.000000e+00
# 75%          NaN      NaN  1.744000e+03     1.100000e+01  1.100000e+01
# max          NaN      NaN  2.400000e+03     7.223000e+03  7.223000e+03
#
#              ArrTime  ArrDelayMinutes       AirTime  CRSElapsedTime  \
# ...

# %%
df.describe(include='all')
# Out:
#         FlightDate                 Airline   Origin     Dest Cancelled  \
# count      4078318                 4078318  4078318  4078318   4078318
# unique         212                      21      375      375         2
# top     2022-07-21  Southwest Airlines Co.      ATL      ATL     False
# freq         20844                  731925   183697   183671   3955126
# mean           NaN                     NaN      NaN      NaN       NaN
# std            NaN                     NaN      NaN      NaN       NaN
# min            NaN                     NaN      NaN      NaN       NaN
# 25%            NaN                     NaN      NaN      NaN       NaN
# 50%            NaN                     NaN      NaN      NaN       NaN
# 75%            NaN                     NaN      NaN      NaN       NaN
# max            NaN                     NaN      NaN      NaN       NaN
#
#        Diverted    CRSDepTime       DepTime  DepDelayMinutes      DepDelay  \
# ...

# %% [markdown]
# # Columns Access

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4078318, step=1)

# %%
pd.set_option('display.max_columns', None)

# %%
df.nunique()
# Out:
# FlightDate            212
# Airline                21
# Origin                375
# Dest                  375
# Cancelled               2
#                      ...
# ArrDel15                2
# ArrivalDelayGroups     15
# ArrTimeBlk             19
# DistanceGroup          11
# DivAirportLandings      5
# Length: 61, dtype: int64

# %%
# access to the specific column(s)
df['Airline']
# Out:
# 0          Commutair Aka Champlain Enterprises, Inc.
# 1          Commutair Aka Champlain Enterprises, Inc.
# 2          Commutair Aka Champlain Enterprises, Inc.
# 3          Commutair Aka Champlain Enterprises, Inc.
# 4          Commutair Aka Champlain Enterprises, Inc.
#                              ...
# 4078313                            Republic Airlines
# 4078314                            Republic Airlines
# 4078315                            Republic Airlines
# 4078316                            Republic Airlines
# 4078317                            Republic Airlines
# Name: Airline, Length: 4078318, dtype: object

# %%
df.Airline
# Out:
# 0          Commutair Aka Champlain Enterprises, Inc.
# 1          Commutair Aka Champlain Enterprises, Inc.
# 2          Commutair Aka Champlain Enterprises, Inc.
# 3          Commutair Aka Champlain Enterprises, Inc.
# 4          Commutair Aka Champlain Enterprises, Inc.
#                              ...
# 4078313                            Republic Airlines
# 4078314                            Republic Airlines
# 4078315                            Republic Airlines
# 4078316                            Republic Airlines
# 4078317                            Republic Airlines
# Name: Airline, Length: 4078318, dtype: object

# %%
df[['Airline']]
# Out:
#                                            Airline
# 0        Commutair Aka Champlain Enterprises, Inc.
# 1        Commutair Aka Champlain Enterprises, Inc.
# 2        Commutair Aka Champlain Enterprises, Inc.
# 3        Commutair Aka Champlain Enterprises, Inc.
# 4        Commutair Aka Champlain Enterprises, Inc.
# ...                                            ...
# 4078313                          Republic Airlines
# 4078314                          Republic Airlines
# 4078315                          Republic Airlines
# 4078316                          Republic Airlines
# 4078317                          Republic Airlines
#
# [4078318 rows x 1 columns]

# %%
df[['Airline', 'Origin', 'Dest']]
# Out:
#                                            Airline Origin Dest
# 0        Commutair Aka Champlain Enterprises, Inc.    GJT  DEN
# 1        Commutair Aka Champlain Enterprises, Inc.    HRL  IAH
# 2        Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# 3        Commutair Aka Champlain Enterprises, Inc.    IAH  GPT
# 4        Commutair Aka Champlain Enterprises, Inc.    DRO  DEN
# ...                                            ...    ...  ...
# 4078313                          Republic Airlines    MSY  EWR
# 4078314                          Republic Airlines    CLT  EWR
# 4078315                          Republic Airlines    ALB  ORD
# 4078316                          Republic Airlines    EWR  PIT
# 4078317                          Republic Airlines    EWR  RDU
#
# [4078318 rows x 3 columns]

# %%
df[df.columns[-4:-1]]
# Out:
#          ArrivalDelayGroups ArrTimeBlk  DistanceGroup
# 0                      -2.0  1200-1259              1
# 1                      -1.0  0800-0859              2
# 2                      -1.0  1600-1659              2
# 3                      -2.0  1600-1659              2
# 4                       0.0  1200-1259              2
# ...                     ...        ...            ...
# 4078313                 NaN  2300-2359              5
# 4078314                 NaN  1900-1959              3
# 4078315                12.0  1800-1859              3
# 4078316                 NaN  2200-2259              2
# 4078317                 NaN  1300-1359              2
#
# [4078318 rows x 3 columns]

# %%
df['Airline'].describe()
# Out:
# count                    4078318
# unique                        21
# top       Southwest Airlines Co.
# freq                      731925
# Name: Airline, dtype: object

# %%
df['Airline'].nunique()
# Out:
# 21

# %%
df['Airline'].unique()
# Out:
# array(['Commutair Aka Champlain Enterprises, Inc.',
#        'GoJet Airlines, LLC d/b/a United Express',
#        'Air Wisconsin Airlines Corp', 'Mesa Airlines Inc.',
#        'Southwest Airlines Co.', 'Republic Airlines', 'Endeavor Air Inc.',
#        'American Airlines Inc.', 'Capital Cargo International',
#        'SkyWest Airlines Inc.', 'Alaska Airlines Inc.', 'JetBlue Airways',
#        'Delta Air Lines Inc.', 'Frontier Airlines Inc.', 'Allegiant Air',
#        'Hawaiian Airlines Inc.', 'Envoy Air', 'Spirit Air Lines',
#        'Comair Inc.', 'Horizon Air', 'United Air Lines Inc.'],
#       dtype=object)

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Southwest Airlines Co.                       731925
# Delta Air Lines Inc.                         512114
# American Airlines Inc.                       495953
# SkyWest Airlines Inc.                        440807
# United Air Lines Inc.                        352009
# Republic Airlines                            197881
# JetBlue Airways                              156793
# Envoy Air                                    150758
# Endeavor Air Inc.                            142624
# Comair Inc.                                  135884
# Alaska Airlines Inc.                         129510
# Spirit Air Lines                             129208
# Frontier Airlines Inc.                        86557
# Allegiant Air                                 73504
# Mesa Airlines Inc.                            71972
# Horizon Air                                   56320
# Capital Cargo International                   52827
# Commutair Aka Champlain Enterprises, Inc.     44367
# ...

# %%
# return output in dataframe shape
df['Airline'].value_counts().reset_index()
# Out:
#                                       Airline   count
# 0                      Southwest Airlines Co.  731925
# 1                        Delta Air Lines Inc.  512114
# 2                      American Airlines Inc.  495953
# 3                       SkyWest Airlines Inc.  440807
# 4                       United Air Lines Inc.  352009
# 5                           Republic Airlines  197881
# 6                             JetBlue Airways  156793
# 7                                   Envoy Air  150758
# 8                           Endeavor Air Inc.  142624
# 9                                 Comair Inc.  135884
# 10                       Alaska Airlines Inc.  129510
# 11                           Spirit Air Lines  129208
# 12                     Frontier Airlines Inc.   86557
# 13                              Allegiant Air   73504
# 14                         Mesa Airlines Inc.   71972
# 15                                Horizon Air   56320
# ...

# %%
df[['Airline', 'Origin']].value_counts()
# Out:
# Airline                                   Origin
# Delta Air Lines Inc.                      ATL       120919
# American Airlines Inc.                    DFW        81239
#                                           CLT        57914
# United Air Lines Inc.                     DEN        46489
# Southwest Airlines Co.                    DEN        45398
#                                                      ...
# Frontier Airlines Inc.                    ICT            1
# GoJet Airlines, LLC d/b/a United Express  BWI            1
# Endeavor Air Inc.                         ECP            1
# Mesa Airlines Inc.                        MDT            1
# Air Wisconsin Airlines Corp               FWA            1
# Name: count, Length: 2194, dtype: int64

# %%
df[['Airline', 'Origin']].value_counts().reset_index()
# Out:
#                                        Airline Origin   count
# 0                         Delta Air Lines Inc.    ATL  120919
# 1                       American Airlines Inc.    DFW   81239
# 2                       American Airlines Inc.    CLT   57914
# 3                        United Air Lines Inc.    DEN   46489
# 4                       Southwest Airlines Co.    DEN   45398
# ...                                        ...    ...     ...
# 2189                    Frontier Airlines Inc.    ICT       1
# 2190  GoJet Airlines, LLC d/b/a United Express    BWI       1
# 2191                         Endeavor Air Inc.    ECP       1
# 2192                        Mesa Airlines Inc.    MDT       1
# 2193               Air Wisconsin Airlines Corp    FWA       1
#
# [2194 rows x 3 columns]

# %%
df['test1'] = 1
df['DepTimeHour'] = df['DepTime']/60

# %%
df.shape
# Out:
# (4078318, 63)

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
df = df.rename(columns = {'test1':'Ones'})

# %%
df.columns
# Out:
# Index(['FlightDate', 'Airline', 'Origin', 'Dest', 'Cancelled', 'Diverted',
#        'CRSDepTime', 'DepTime', 'DepDelayMinutes', 'DepDelay', 'ArrTime',
#        'ArrDelayMinutes', 'AirTime', 'CRSElapsedTime', 'ActualElapsedTime',
#        'Distance', 'Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        'Flight_Number_Marketing_Airline', 'Operating_Airline',
#        'DOT_ID_Operating_Airline', 'IATA_Code_Operating_Airline',
#        'Tail_Number', 'Flight_Number_Operating_Airline', 'OriginAirportID',
#        'OriginAirportSeqID', 'OriginCityMarketID', 'OriginCityName',
#        'OriginState', 'OriginStateFips', 'OriginStateName', 'OriginWac',
#        'DestAirportID', 'DestAirportSeqID', 'DestCityMarketID', 'DestCityName',
#        'DestState', 'DestStateFips', 'DestStateName', 'DestWac', 'DepDel15',
# ...

# %%
df = df.sort_values(['Airline', 'Origin'])
df.tail(5)
# Out:
#          FlightDate                Airline Origin Dest  Cancelled  Diverted  \
# 2405130  2022-06-29  United Air Lines Inc.    TVC  ORD      False     False
# 2408784  2022-06-27  United Air Lines Inc.    TVC  ORD      False     False
# 2424220  2022-06-26  United Air Lines Inc.    TVC  ORD      False     False
# 2425934  2022-06-25  United Air Lines Inc.    TVC  ORD      False     False
# 2427568  2022-06-24  United Air Lines Inc.    TVC  ORD      False     False
#
#          CRSDepTime  DepTime  DepDelayMinutes  DepDelay  ArrTime  \
# 2405130         730    728.0              0.0      -2.0    745.0
# 2408784         730    847.0             77.0      77.0    849.0
# 2424220         600    559.0              0.0      -1.0    559.0
# 2425934         730    721.0              0.0      -9.0    731.0
# 2427568         730    727.0              0.0      -3.0    730.0
#
#          ArrDelayMinutes  AirTime  CRSElapsedTime  ActualElapsedTime  \
# ...

# %% [markdown]
# ## Rows Access
